# %% [markdown]
# ## Libras Detection

# %%
# %pip install cvzone mediapipe opencv-python numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Acessar as pastas com as imagens tiradas e fazer um loop em cada imagem das maos

# %%
# acessar a pasta Folds_Dataset_Final
import os
import shutil
folder_path = os.path.abspath('../Folds_Dataset_Final/')

if os.path.isdir(folder_path):
  content = os.listdir(folder_path)

  for item in content:
    new_folder = item
    new_path = os.path.join(folder_path,new_folder)

    content1 = os.listdir(new_path)

    for item in content1:
      
      new_folder_2 = item
      new_path_2 = os.path.join(new_path,new_folder_2)
      print(new_path_2)
      mask = 'mask'
      maskfolder = os.path.join(new_path_2,mask)
      
      if not os.path.exists(maskfolder):
        os.mkdir(maskfolder)
      else:
        print('pasta já criada')
     
      content2 = os.listdir(new_path_2)
      
      # loop interno dentro de cada pasta para separ as imagens das mascaras
      for item in content2:
        if item.startswith('c'):
          path_origin = os.path.join(new_path_2,item)
          path_destination = os.path.join(maskfolder,item)
          shutil.move(path_origin,path_destination)
# Out:
# /home/guilherme/Documentos/GitHub/Sariema_IA/Folds_Dataset_Final/Fold2/2
# pasta já criada
# /home/guilherme/Documentos/GitHub/Sariema_IA/Folds_Dataset_Final/Fold2/Pequeno
# pasta já criada
# /home/guilherme/Documentos/GitHub/Sariema_IA/Folds_Dataset_Final/Fold2/Verbo
# pasta já criada
# /home/guilherme/Documentos/GitHub/Sariema_IA/Folds_Dataset_Final/Fold2/D
# pasta já criada
# /home/guilherme/Documentos/GitHub/Sariema_IA/Folds_Dataset_Final/Fold2/Palavra
# pasta já criada
# /home/guilherme/Documentos/GitHub/Sariema_IA/Folds_Dataset_Final/Fold2/5
# pasta já criada
# /home/guilherme/Documentos/GitHub/Sariema_IA/Folds_Dataset_Final/Fold2/F
# pasta já criada
# /home/guilherme/Documentos/GitHub/Sariema_IA/Folds_Dataset_Final/Fold2/Aviao
# pasta já criada
# /home/guilherme/Documentos/GitHub/Sariema_IA/Folds_Dataset_Final/Fold2/Pedra
# pasta já criada
# /home/guilherme/Documentos/GitHub/Sariema_IA/Folds_Dataset_Final/Fold2/L
# pasta já criada
# ...

# %% [markdown]
# Teste dos pontos de articulação na mão

# %%
import cv2
import mediapipe as mp
# Out:
# 2023-05-29 13:20:18.299260: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-29 13:20:18.486382: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/guilherme/.local/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-05-29 13:20:18.486404: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %%
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(static_image_mode=True, max_num_hands=1)

imagem = cv2.imread('./mao.jpg')

img_rgb = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)
imgResize = cv2.resize(img_rgb,(250,250))

print(imgResize.shape)

cv2.imshow('img',imgResize)

resultados = hands.process(imgResize)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (250, 250, 3)

# %%
if resultado.multi_hand_landmarks:
    print('cheguei')
    for mao_landmarks in resultado.multi_hand_landmarks:
        # Iterar sobre os pontos de referência da mão
        for ponto_referencia in mao_landmarks.landmark:
            # Extrair as coordenadas normalizadas (x, y) do ponto de referência
            coordenada_x = ponto_referencia.x
            coordenada_y = ponto_referencia.y
            
            # Converter as coordenadas normalizadas para pixels
            altura, largura, _ = imagem.shape
            pixel_x = int(coordenada_x * largura)
            pixel_y = int(coordenada_y * altura)
            print(pixel_x,pixel_y)
            # Desenhar um círculo vermelho no ponto de referência na imagem
            cv2.circle(imagem, (pixel_x, pixel_y), 5, (0, 0, 255), -1)

# %%
print(resultado.multi_hand_landmarks)
# Out:
# None

# %% [markdown]
# Teste com media pipe

# %%
# STEP 1: Import the necessary modules.
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
import cv2
# Out:
# 2023-05-30 19:08:16.234481: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-30 19:08:16.485281: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/guilherme/.local/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-05-30 19:08:16.485304: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %%
# !wget -q https://storage.googleapis.com/mediapipe-models/hand_landmarker/hand_landmarker/float16/1/hand_landmarker.task

# %%
#@markdown We implemented some functions to visualize the hand landmark detection results. <br/> Run the following cell to activate the functions.

from mediapipe import solutions
from mediapipe.framework.formats import landmark_pb2
import numpy as np

MARGIN = 10  # pixels
FONT_SIZE = 1
FONT_THICKNESS = 1
HANDEDNESS_TEXT_COLOR = (88, 205, 54) # vibrant green

def draw_landmarks_on_image(rgb_image, detection_result):
  hand_landmarks_list = detection_result.hand_landmarks
  handedness_list = detection_result.handedness
  annotated_image = np.copy(rgb_image)

  # Loop through the detected hands to visualize.
  for idx in range(len(hand_landmarks_list)):
    hand_landmarks = hand_landmarks_list[idx]
    handedness = handedness_list[idx]

    # Draw the hand landmarks.
    hand_landmarks_proto = landmark_pb2.NormalizedLandmarkList()
    hand_landmarks_proto.landmark.extend([
      landmark_pb2.NormalizedLandmark(x=landmark.x, y=landmark.y, z=landmark.z) for landmark in hand_landmarks
    ])
    solutions.drawing_utils.draw_landmarks(
      annotated_image,
      hand_landmarks_proto,
      solutions.hands.HAND_CONNECTIONS,
      solutions.drawing_styles.get_default_hand_landmarks_style(),
      solutions.drawing_styles.get_default_hand_connections_style())

    # Get the top left corner of the detected hand's bounding box.
    height, width, _ = annotated_image.shape
    x_coordinates = [landmark.x for landmark in hand_landmarks]
    y_coordinates = [landmark.y for landmark in hand_landmarks]
    text_x = int(min(x_coordinates) * width)
    text_y = int(min(y_coordinates) * height) - MARGIN

    # Draw handedness (left or right hand) on the image.
    cv2.putText(annotated_image, f"{handedness[0].category_name}",
                (text_x, text_y), cv2.FONT_HERSHEY_DUPLEX,
                FONT_SIZE, HANDEDNESS_TEXT_COLOR, FONT_THICKNESS, cv2.LINE_AA)

  return annotated_image

# %%
# STEP 2: Create an HandLandmarker object.
base_options = python.BaseOptions(model_asset_path='hand_landmarker.task')
options = vision.HandLandmarkerOptions(base_options=base_options,
                                       num_hands=1)
detector = vision.HandLandmarker.create_from_options(options)

# %%
# STEP 3: Load the input image.
image = mp.Image.create_from_file("hand_image.jpg")

# %%
# STEP 4: Detect hand landmarks from the input image.
detection_result = detector.detect(image)

# %%
import cv2

# %%
# STEP 5: Process the classification result. In this case, visualize it.
annotated_image = draw_landmarks_on_image(image.numpy_view(), detection_result)
cv2.imshow('img',cv2.cvtColor(annotated_image, cv2.COLOR_RGB2BGR))
cv2.waitKey(0)
cv2.destroyAllWindows()
